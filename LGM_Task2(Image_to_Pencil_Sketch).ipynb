# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image=cv2.imread("/content/shinchan.jpg")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=499x640 at 0x7F94BC35FFD0>

# %%
#grayscale image
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=499x640 at 0x7F94EAF3FD30>

# %%
#negative image
inverted_image=255-gray_image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=499x640 at 0x7F94F00335B0>

# %%
#blur image
blurred=cv2.GaussianBlur(inverted_image,(21,21),0)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=L size=499x640 at 0x7F94EAF3FD00>

# %%
inverted_blurred=255-blurred
pencil_sketch=cv2.divide(gray_image,inverted_blurred,scale=256.0)
#Original image
cv2_imshow(image)
#pencil sketch
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=499x640 at 0x7F94BC35FBB0>
# <PIL.Image.Image image mode=L size=499x640 at 0x7F94BC35FD30>
